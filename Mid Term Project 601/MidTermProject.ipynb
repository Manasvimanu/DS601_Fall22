# %% [markdown]
# # DATA 601 MID-TERM PROJECT
#
# ### Name of the Dataset: DC Mayor's office of Planning and Economic Development
#
# Data Scource Location:
#
# https://data.world/codefordc/great-streets/workspace/file?filename=Great+Streets+Grantees.csv In the above link inside the data folder we are using filename "Great+Streets+Grantees.csv" is the data which I am using in the project Description of how data is found: When I was looking for an intresting data set in the finance sectors to play with numbers, I found this dataset which includes the details of the employees, projects retained by the comapny and Officail Amount earned by the company in the financial year.
#
# Dataset Size: 38.01KB
#
# Our Dataset contains 1 table
#
# The shape of our dataset is 219 rows and 15 columns

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#reading dataset
df = pd.read_csv('mid_term_dataset.csv',encoding='latin-1')

# %%
#displaying first 4 rows
df.head(4)
# Out:
#                                  Prospect Name       Great Streets Corridor  \
# 0  Ask Investment Corp dba Dollar Plus Savings  7th St NW/Georgia Avenue NW
# 1       Compass Coffee, LLC dba Compass Coffee  7th St NW/Georgia Avenue NW
# 2                                  Ivy & Coney  7th St NW/Georgia Avenue NW
# 3                       Gwynn Inc. dba Halcyon  7th St NW/Georgia Avenue NW
#
#   Official Amount  Fiscal Year    Business Address        City State  \
# 0     $85,000.00          2013  1547 7th Street NW  Washington    DC
# 1     $85,000.00          2014  1535 7th Street NW  Washington    DC
# 2     $85,000.00          2014  1537 7th Street NW  Washington    DC
# 3     $85,000.00          2014  1326 8th Street NW  Washington    DC
#
#    Zip Code      Business Type    Ward  Latitude  Longitude  \
# 0     20001  Convenience Store  Ward 6  38.91093  -77.02172
# 1     20001        Coffee Shop  Ward 6  38.91062  -77.02158
# ...

# %% [markdown]
# Displaying the first 4 rows in the dataset using head() method

# %%
#Shape of the dataset
df.shape
# Out:
# (219, 15)

# %% [markdown]
# The dataset has 219 rows and 15 columns

# %%
#Different dataset types
df.dtypes
# Out:
# Prospect Name                               object
# Great Streets Corridor                      object
# Official Amount                             object
# Fiscal Year                                  int64
# Business Address                            object
# City                                        object
# State                                       object
# Zip Code                                     int64
# Business Type                               object
# Ward                                        object
# Latitude                                   float64
# Longitude                                  float64
# Total Number of Projected/Retained Jobs    float64
# Total Projected Number of Jobs             float64
# Total Number of Employees Retained         float64
# dtype: object

# %% [markdown]
# The dataset contains different datatypes such as object,integer and float

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ### Dropping the columns that does not have a significant use for all the data those are City, State, Zip Code, latitude, longitude.

# %%
df = df.drop(['City', 'State', 'Zip Code', 'Latitude', 'Longitude'], axis = 1)

# %%
df.head()
# Out:
#                                  Prospect Name       Great Streets Corridor  \
# 0  Ask Investment Corp dba Dollar Plus Savings  7th St NW/Georgia Avenue NW
# 1       Compass Coffee, LLC dba Compass Coffee  7th St NW/Georgia Avenue NW
# 2                                  Ivy & Coney  7th St NW/Georgia Avenue NW
# 3                       Gwynn Inc. dba Halcyon  7th St NW/Georgia Avenue NW
# 4      Henderson Enterprise dba Wanda's on 7th  7th St NW/Georgia Avenue NW
#
#   Official Amount  Fiscal Year    Business Address      Business Type    Ward  \
# 0     $85,000.00          2013  1547 7th Street NW  Convenience Store  Ward 6
# 1     $85,000.00          2014  1535 7th Street NW        Coffee Shop  Ward 6
# 2     $85,000.00          2014  1537 7th Street NW         Restaurant  Ward 6
# 3     $85,000.00          2014  1326 8th Street NW   Salon/Barbershop  Ward 6
# 4     $74,719.28          2014  1851 7th Street NW   Salon/Barbershop  Ward 1
#
# ...

# %%
df.tail()
# Out:
#                                          Prospect Name  \
# 214                  The Mediterranean Spot & More LLC
# 215                El Tamarindo, Inc. dba El Tamarindo
# 216      Purple Patch, LLC dba Purple Patch Restaurant
# 217                          Le Bustiere Boutique, LLC
# 218  Rachel Joyce Studios, LLC dba Rachel Joyce Org...
#
#       Great Streets Corridor Official Amount  Fiscal Year  \
# 214  U Street/14th Street NW     $40,000.00          2016
# 215  U Street/14th Street NW     $37,500.00          2016
# 216  U Street/14th Street NW     $40,000.00          2016
# 217  U Street/14th Street NW     $25,000.00          2016
# 218  U Street/14th Street NW     $18,477.00          2016
#
#                   Business Address Business Type    Ward  \
# 214               1501 U Street NW    Restaurant  Ward 1
# 215         1785 Florida Avenue NW    Restaurant  Ward 1
# 216  3155 Mount Pleasant Street NW    Restaurant  Ward 1
# ...

# %% [markdown]
# In the above dataset, there are few rows which does'nt have significant use so that we can delete them

# %% [markdown]
# ## Missing Values

# %%
df.isna().sum()
# Out:
# Prospect Name                               0
# Great Streets Corridor                      0
# Official Amount                             0
# Fiscal Year                                 0
# Business Address                            0
# Business Type                               0
# Ward                                        0
# Total Number of Projected/Retained Jobs     1
# Total Projected Number of Jobs             26
# Total Number of Employees Retained         30
# dtype: int64

# %% [markdown]
# Checking for null values in the dataset

# %%
df = df.dropna()
df
# Out:
#                                          Prospect Name  \
# 0          Ask Investment Corp dba Dollar Plus Savings
# 2                                          Ivy & Coney
# 3                               Gwynn Inc. dba Halcyon
# 4              Henderson Enterprise dba Wanda's on 7th
# 5          Pekoe Acupuncture and Wellness Center, PLLC
# ..                                                 ...
# 214                  The Mediterranean Spot & More LLC
# 215                El Tamarindo, Inc. dba El Tamarindo
# 216      Purple Patch, LLC dba Purple Patch Restaurant
# 217                          Le Bustiere Boutique, LLC
# 218  Rachel Joyce Studios, LLC dba Rachel Joyce Org...
#
#           Great Streets Corridor Official Amount  Fiscal Year  \
# 0    7th St NW/Georgia Avenue NW     $85,000.00          2013
# 2    7th St NW/Georgia Avenue NW     $85,000.00          2014
# 3    7th St NW/Georgia Avenue NW     $85,000.00          2014
# ...

# %% [markdown]
# #### Dropping the null values from the dataset

# %%
df.isna().sum()
# Out:
# Prospect Name                              0
# Great Streets Corridor                     0
# Official Amount                            0
# Fiscal Year                                0
# Business Address                           0
# Business Type                              0
# Ward                                       0
# Total Number of Projected/Retained Jobs    0
# Total Projected Number of Jobs             0
# Total Number of Employees Retained         0
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
# Displaying the histogram plot 
plt.hist(x = 'Total Number of Projected/Retained Jobs', data = df,  color = "orange")
plt.xlabel("Retained Jobs")
# Out:
# Text(0.5, 0, 'Retained Jobs')

# %% [markdown]
# Visualizing the data using Histogram which shows total no of projected/retained jobs

# %%
# Displaying the count plot
plt.figure(figsize=(20,10))
sns.countplot(df['Fiscal Year'], hue = df['Total Number of Employees Retained'])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Visualizing the data using count plot comparing the fiscal year with Total Number of Employees Retained

# %%
sns.displot(data=df,kind="ecdf",x="Fiscal Year",hue="Total Number of Projected/Retained Jobs",aspect=1.5)
plt.xlabel('Fiancial Year')
plt.ylabel('Retained Jobs')


sns.displot(data=df,kind="ecdf",x="Fiscal Year",hue="Total Projected Number of Jobs",aspect=1.5)
plt.xlabel('Fiancial Year')
plt.ylabel('Projected Number of Jobs')


sns.displot(data=df,kind="ecdf",x="Fiscal Year",hue="Total Number of Employees Retained",aspect=1.5)
plt.xlabel('Fiancial Year')
plt.ylabel('Employees Retained')
# Out:
# Text(18.809953703703698, 0.5, 'Employees Retained')

# %% [markdown]
# #### The above three graphs represent the Number of Jobs Retained, Projected number of jobs and Employee retained in the financial year

# %%
plot = sns.displot(df, x="Ward", y="Total Number of Projected/Retained Jobs", cbar = True)
plot.ax.tick_params(labelrotation = 45)
#plot.ax.set_title('Distribution between Counties and License types')

# %% [markdown]
# #### Visualizing the data using displot comparing Ward in x-axis and Total Number of Projected/Retained Jobs in y-axis

# %%
plt.scatter(data = df, x="Ward", y="Total Number of Employees Retained")
plt.xlabel("Ward")
plt.ylabel("Total Number of Employees Retained")
# Out:
# Text(0, 0.5, 'Total Number of Employees Retained')

# %% [markdown]
# #### Visualizing the data using scatterplot comparing ward and no of employees retained

# %%
plot = sns.displot(df, x="Ward", y="Total Projected Number of Jobs", cbar = True)
plot.ax.tick_params(labelrotation = 45)

# %% [markdown]
# #### Visualizing the data using scatterplot comparing ward and projected number of jobs

# %%
plot = sns.displot(df, x="Fiscal Year", y="Official Amount", height = 10)
plot.ax.tick_params()

# %% [markdown]
# #### Visualizing the data using displot comparing fiscal year in x-axis and official amount in y-axis

# %%
sns.pairplot(df)

# %% [markdown]
# #### The above data set represents the information of DC Mayor's office of Planning and Economic Development(datast).
# #### The variables can be both continuous or categorical. Using the Seaborn Pairplot, we can visualize pairwise correlations between variables in a dataset.

# %% [markdown]
# #### CONCLUSION:
#
# From the graphs above we can see that in between 2013-2014 the employees that have been retained is maximum.
#
# In the next sub graphs we can see that comparision with count between the retained jobs, projected number of jobs and Employees retained - we can see that in the year 2015 Retained Jobs, Projected Number of Jobs and Employees that are been retained are highest.
#
# In the next displot plot we can see that Ward 1 has reatined the maximum number of jobs, but Ward 5 have retained many jobs which fall in the range of 10 in each financial year which might combine to make it strong.
#
# We can see that the Ward 1 has the maximum number of Retained jobs which means that they will need the maximum workforce. So, we can see in the next graph that Ward 1 has also retained the maximum number of jobs
#
# From the Financial Year v/s Offical Amount Graph we can see that in the year 2014 the maximum Amount has been gained that is $85,000.00
