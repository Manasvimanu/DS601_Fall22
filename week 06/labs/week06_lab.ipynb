# %% [markdown]
# # Week6 Lab
#
# ## Download & Extract Data
#
# Programmatically download the zip file & extract

# %%
from urllib import request

def download_file(file_name, url):
    res = request.urlopen(url)
    with open(file_name,'wb') as file:
        file.write(res.read())

# %%
file_url = 'https://github.com/msaricaumbc/DS_data/blob/master/lab_data.zip?raw=true'
file_name = 'lab_data.zip'

# %%
download_file(file_name,file_url)

# %%
from zipfile import ZipFile
def unzip(file_name, path='./'):
    with ZipFile(file_name, 'r') as zip:
        zip.printdir()
        print('Extracting all the files now...') 
        zip.extractall(path = path) 
        print('Done!') 
unzip(file_name)
# Out:
# File Name                                             Modified             Size
# PoliceShootingsUS.csv                          2021-09-21 20:53:54       227653
# __MACOSX/._PoliceShootingsUS.csv               2021-09-21 20:53:54          276
# volunteers.txt                                 2021-10-06 00:32:28         7015
# __MACOSX/._volunteers.txt                      2021-10-06 00:32:28          176
# Extracting all the files now...
# Done!

# %% [markdown]
# ## Reading data from a csv file

# %% [markdown]
# For the file `PoliceShootingsUS.csv`, please answer the following questions:
#
# * How many offenders are older than 55?

# %%
## Your code is here
import pandas as pd
Policedata=pd.read_csv('PoliceShootingsUS.csv',encoding='Windows_1252')
Policedata
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 0         M    A        Shelton    WA                     True       attack
# 1         M    W          Aloha    OR                    False       attack
# 2         M    H        Wichita    KS                    False        other
# 3         M    W  San Francisco    CA                     True       attack
# 4         M    H          Evans    CO                    False       attack
# ...     ...  ...            ...   ...                      ...          ...
# 2530      M  NaN    Kansas City    MO                    False       attack
# 2531      M  NaN    Albuquerque    NM                    False       attack
# 2532      M  NaN          Melba    ID                    False       attack
# 2533      M    B        Oshkosh    WI                    False       attack
# 2534      M    B       Brooklyn    NY                     True       attack
#
#              flee  body_camera
# 0     Not fleeing        False
# 1     Not fleeing        False
# 2     Not fleeing        False
# 3     Not fleeing        False
# 4     Not fleeing        False
# ...           ...          ...
# 2530  Not fleeing        False
# 2531          Car        False
# 2532          Car        False
# 2533          Car         True
# 2534  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
Policedata[Policedata.age>55]
# Out:
#         id                  name      date   manner_of_death  armed   age  \
# 19      38         Jimmy Foreman  09/01/15              shot    gun  71.0
# 29      52      Talbot Schroeder  14/01/15              shot  knife  75.0
# 30      54        Robert Edwards  14/01/15              shot    gun  68.0
# 43      83         Carter Castle  18/01/15  shot and Tasered    gun  67.0
# 52     336  Robert Francis Mesch  23/01/15              shot    gun  61.0
# ...    ...                   ...       ...               ...    ...   ...
# 2432  2692  Lawrence Heyward Jr.  25/06/17              shot    gun  56.0
# 2490  2775        Stephen Steele  13/07/17              shot  knife  56.0
# 2502  2787   Robert Earl Vaughan  18/07/17              shot    gun  70.0
# 2512  2796     Michael Caponigro  23/07/17              shot    gun  59.0
# 2522  2807            Susan Teel  26/07/17              shot  knife  62.0
#
#      gender race              city state  signs_of_mental_illness  \
# 19        M    W           England    AR                    False
# 29        M    W        Old Bridge    NJ                    False
# 30        M    W      Lake Jackson    TX                    False
# 43        M    W           Gunlock    KY                     True
# 52        M    W            Austin    TX                     True
# ...     ...  ...               ...   ...                      ...
# 2432      M    B  North Charleston    SC                    False
# 2490      M  NaN   Crystal Springs    FL                     True
# 2502      M  NaN       Springfield    OR                     True
# 2512      M    W        Eau Claire    WI                     True
# 2522      F  NaN        Vero Beach    FL                     True
#
#       threat_level         flee  body_camera
# 19          attack  Not fleeing        False
# 29          attack  Not fleeing        False
# 30          attack  Not fleeing        False
# 43          attack  Not fleeing        False
# 52          attack  Not fleeing        False
# ...            ...          ...          ...
# 2432  undetermined         Foot        False
# 2490         other  Not fleeing        False
# 2502         other  Not fleeing        False
# 2512        attack  Not fleeing        False
# 2522        attack  Not fleeing        False
#
# [235 rows x 14 columns]

# %%
Policedata[Policedata.age>55].count()
# Out:
# id                         235
# name                       235
# date                       235
# manner_of_death            235
# armed                      234
# age                        235
# gender                     235
# race                       211
# city                       235
# state                      235
# signs_of_mental_illness    235
# threat_level               235
# flee                       228
# body_camera                235
# dtype: int64

# %% [markdown]
# * What's the age distribution?

# %%
## Your code is here
import seaborn as sns
plt = sns.displot(data = Policedata, x= 'age', kind = 'kde', height= 4, aspect = 3)
plt.ax.grid(axis = 'x')

# %%
plt = sns.displot(data = Policedata, x= 'age', kind = 'hist', height= 4, aspect = 3)
plt.ax.grid(axis = 'x')

# %% [markdown]
# ## Dirty data
#
# Read `volunteers.txt` file and perform the following action:
#
# * Create a dataframe with columns: Name, Lastname, State

# %%
## Your code is here
names=[]
lastnames = []
states = []

with open('volunteers.txt', 'r') as file:
    line = file.readlines()
    for line in line:
        line = line \
        .replace(('"'), ',') \
        .replace(('['), ',') \
        .replace((']'), ',') \
        .replace(('('), ',') \
        .replace((')'), ',') \
        .replace(('-'), ',')
        parts = line.split(',')
        lastname = parts[3].strip()
        name = parts[4].strip()
        state = parts[6].strip()
        names.append(name)
        lastnames.append(lastname)
        states.append(state)
dataframe = pd.DataFrame()
dataframe['Names'] = names
dataframe['Lastname'] = lastnames
dataframe['State'] = states
dataframe
# Out:
#         Names  Lastname         State
# 0   Christine   Harding      Virginia
# 1    Kimberly     Davis      New York
# 2      Rachel    Ingram     Louisiana
# 3     Richard    Walker        Oregon
# 4   Francisco    Barnes      Virginia
# ..        ...       ...           ...
# 95      Kevin     Smith  North Dakota
# 96       Mark     Moore        Alaska
# 97   Jennifer    Landry       Wyoming
# 98       Lori  Phillips      Arkansas
# 99    Tiffany     Davis   Mississippi
#
# [100 rows x 3 columns]
