# %% [markdown]
# # Lab

# %% [markdown]
# Using the flights dataframe answer the following questions

# %% [markdown]
# 1. When do the first and last flights leave each day?
#
# 2. When there is a missing value in `dep_time` then this is an indication of canceled flight. Find the number of cancelled flights for each (`carrier`, `origin`) combination.
#
# 3. Which carrier has the worst `dep_delay`s?
#
# 4. Which plane (`tailnum`) has the worst on-time record?
#
# 5. For each plane, count the number of flights before the first delay of greater than 1 hour.

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/msaricaumbc/DS_data/master/nyc_flights.csv'

flights = pd.read_csv(url)

# %%
flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
A = flights[~(flights.dep_time.isnull())]
A1 = A.groupby(['month','day']).head(2)
A2 = A.groupby(['month','day']).tail(2)
A3 = A1.append(A2)
A3.sort_values(by=['month','day'])
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 836     2013      1    1    2353.0            2359       -6.0     418.0
# 837     2013      1    1    2356.0            2359       -3.0     425.0
# 842     2013      1    2      42.0            2359       43.0     518.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 110505  2013     12   30    2356.0            2200      116.0     154.0
# 110520  2013     12   31      13.0            2359       14.0     439.0
# 110521  2013     12   31      18.0            2359       19.0     449.0
# 111278  2013     12   31    2355.0            2359       -4.0     430.0
# 111279  2013     12   31    2356.0            2359       -3.0     436.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
X1 = flights[flights.dep_time.isnull()]
X1.groupby(['carrier','origin']).agg(
    Canceled_Flights = ('flight','count')
)
# Out:
#                 Canceled_Flights
# carrier origin
# 9E      EWR                   68
#         JFK                  807
#         LGA                  169
# AA      EWR                   99
#         JFK                  141
#         LGA                  396
# AS      EWR                    2
# B6      EWR                   74
#         JFK                  315
#         LGA                   77
# DL      EWR                   39
#         JFK                  100
#         LGA                  210
# EV      EWR                 2164
#         JFK                   82
#         LGA                  571
# F9      LGA                    3
# FL      LGA                   73
# MQ      EWR                  168
#         JFK                  327
#         LGA                  739
# OO      LGA                    3
# UA      EWR                  435
#         JFK                   44
#         LGA                  207
# US      EWR                   75
#         JFK                   26
# ...

# %%
X1 = flights.groupby('carrier').dep_delay.mean()
X1.sort_values(ascending=False).head(2)
# Out:
# carrier
# F9    20.215543
# EV    19.955390
# Name: dep_delay, dtype: float64

# %%
X1 = flights[~(flights.arr_delay.isnull())]
X1.sort_values(by=['arr_delay']).tail(2).tailnum
# Out:
# 235778    N504MQ
# 7072      N384HA
# Name: tailnum, dtype: object

# %%
flights[(flights.arr_delay > 60)].groupby('tailnum').agg({
    'flight': 'count'
})
# Out:
#          flight
# tailnum
# D942DN        1
# N0EGMQ       30
# N10156       15
# N102UW        2
# N104UW        4
# ...         ...
# N997DL        5
# N998AT        3
# N998DL        8
# N999DN        6
# N9EAMQ       21
#
# [3371 rows x 1 columns]

# %%
X1 = flights[~(flights.dep_time.isnull())]
X1
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...
